# %%
#Patrick Dowd
#CSC201
#3/23/2020
#Spring 2020
#Dowd_assignment7
#PROGRAM TITLE- College Major Data and Statistics

#PROGRAM DESCRIPTION - A Python program that provides the user with a list of choices relating
#                      College Major data data and statistics including median salary, and the labor participation rates of 
#                      majors.

#This program gives the user a choice of 5 different statitistics to choose from regarding college major data. This data all 
#comes from my data set that I collected from data.world. its called "all ages". The program starts by prompting the user to 
#enter the number of the statistic they would like to acess. Depending on what number the user enters their input will be 
#entered into a while loop that checks the value they eneterd with 6 different conditional statments the first 4 if statments 
#acess the statistics through variables entered at the beggining of the program the 5th if statment checks for the value '5' 
#in which it will break the while loop and print 'program ended'. Finally the 6th conditional is an else statment essentailly 
#saying that if any value is entered that is not equal to 1, 2, 3, 4 or 5 it will tell the user that their input is invalid 
#and prompt them to try again.

#Data collection: Data.world

print('College Major Data and Statistics')
print('Data collected from Data.World')
#Option 1:
Data = '''Lowest median salary: Nuero Science-$35000
Highest median salary: Petroleum Engineering-$125,000'''
pe = 125000
ns = 35000
difference = pe - ns
ratio = ns/pe
#Option 2:
Data2 = '''Lowest unemployment rate: GEOLOGICAL AND GEOPHYSICAL ENGINEERING- 0.0
Highest unemployment rate: MISCELLANEOUS FINE ARTS- .15'''
percent = .15*100
#Option 3:
Data3 = '''Lowest labor force participation: SCHOOL STUDENT COUNSELING- 2396
Highest labor force participation: BUSINESS MANAGEMENT AND ADMINISTRATION- 3123510'''
B = 3123510
SSC = 2396
difference3 = B-SSC
ratio3 = SSC/B
#Option 4
Data4 = '''Lowest population of full time workers year-round: SCHOOL STUDENT COUNSELING- 1093
Highest population of fulltime workers year-round: BUSINESS MANAGEMENT AND ADMINISTRATION- 1939384'''
B4 = 1939384
SSC4 = 1093
difference4 = B4-SSC4
ratio4 = SSC4/B4
print('''Choose one of the following numbered options to view data and statistics about college majors.
1. Highest vs lowest median salary of major
2. Highest vs lowest unemployment of major
3. highest vs lowest total number of labor force for major
4. Highest vs lowest employed full time year around
5. quit''')
choice = input('Choice:')
if choice == '1' or '2' or '3' or '4':
    while choice == '1' or '2' or '3' or '4':
        if choice == '1':
            print(Data)
            print('difference:', difference)
            print('ratio:', ratio)
            choice = input('Choice:')
        elif choice == '2':
            print(Data2)
            print('Approximatly 0 percent of GEOLOGICAL AND GEOPHYSICAL ENGINEERING graduates are unemployed')
            print('Approximatly', percent, 'percent of MISCELLANEOUS FINE ARTS are unemployed')
            choice = input('Choice:')
        elif choice == '3':
            print(Data3)
            print('Difference:', difference3)
            print('Ratio:', ratio3)
            choice = input('Choice:')
        elif choice == '4':
            print(Data4)
            print('Difference:', difference4)
            print('Ratio:', ratio4)
            choice = input('Choice:')
        elif choice == '5':
            break
        else:
            print('Please enter the number of one of the options provided')
            choice = input('Choice:')


print('program ended')
# Out:
# College Major Data and Statistics
# Data collected from Data.World
# Choose one of the following numbered options to view data and statistics about college majors.
# 1. Highest vs lowest median salary of major
# 2. Highest vs lowest unemployment of major
# 3. highest vs lowest total number of labor force for major
# 4. Highest vs lowest employed full time year around
# 5. quit
# Choice:REEE
# Please enter the number of one of the options provided
# Choice:1
# Lowest median salary: Nuero Science-$35000
# Highest median salary: Petroleum Engineering-$125,000
# difference: 90000
# ratio: 0.28
# Choice:2
# Lowest unemployment rate: GEOLOGICAL AND GEOPHYSICAL ENGINEERING- 0.0
# Highest unemployment rate: MISCELLANEOUS FINE ARTS- .15
# Approximatly 0 percent of GEOLOGICAL AND GEOPHYSICAL ENGINEERING graduates are unemployed
# Approximatly 15.0 percent of MISCELLANEOUS FINE ARTS are unemployed
# Choice:3
# Lowest labor force participation: SCHOOL STUDENT COUNSELING- 2396
# ...
