# %%
import datetime
#Patrick Dowd
#CSC201
#Spring 2020
#program survey
#3/18/2020
#This program acts as a survey to gather data for my CSC project
'''This program prompts users to input data regardiung how and why they chose their college majors. The program
asks users questions via print statments and gives them the opportunity to respond with an input function. There are multiple 
if statments in place to tell the user if a response is deemed invalid by the program they will e given a secon attempt to answer 
the question before the program moves on however any failed attempts will result in the program not printing your survey results at 
the end'''
print(datetime.datetime.today())
print('how old are you?')
age = int(input())
if age < 10 or age > 99:
    print('the age you entered is outside range')
elif age == str:
    remove(str)
else:
    print('what is your current college major?')
major = input()
if major == int:
    print('Invalid value')
    major = input()
    print(major)
else:
    print(major)
    pass
print('what year did you choose your current major?')
answers = ['freshman', 'sophmore', 'junior', 'senior', 'other']
print('answers:', answers)
year = str(input())
if year == year in answers:
    print(year)
    pass
else:
    print('Please enter one of the appropriate answers:')
    year = str(input())
    print(year)
print('How important is median salary to you when considering a major?')
nums = ['1', '2', '3', '4', '5']
print('Not important at all', nums, 'Very important')
salary = input()
if salary == salary in nums:
    print(salary)
    pass
else:
    print('please enter a whole number between 1 and 5')
    salary = float(input())
    print(salary)
print('How important is passion to you when considering a major?')
nums = ['1', '2', '3', '4', '5']
print('Not important at all', nums, 'Very important')
passion = input()
if passion == passion in nums:
    print(passion)
    pass
else:
    print('please enter a whole number between 1 and 5')
    passion = float(input())
    print(passion)
print('would you say that you are passionate about your major?')
answers = ['Yes', 'No', 'Unsure']
print('answers:', answers)
answer = str(input())
if answer == answer in answers:
    print(answer)
    pass
else:
    print('Please enter one of the appropriate answers:')
    answer = str(input())
    print(answer)
print('How important is percieved difficulty to you when considering a major?')
nums = ['1', '2', '3', '4', '5']
print('Not important at all', nums, 'Very important')
difficulty = input()
if difficulty == difficulty in nums:
    print(difficulty)
    pass
else:
    print('please enter a whole number between 1 and 5')
    rating = input()
    print(rating)
print('did you consult your parents before picking a major?')
answers = ['Yes', 'No', 'Unsure']
print('answers:', answers)
ans = str(input())
if ans == ans in answers:
    print(ans)
    pass
else:
    print('Please enter one of the appropriate answers:')
    answer = str(input())
    print(answer)
list = [age, major, year, salary, passion, answer, difficulty, ans]
if len(list) == 8:
    print(list)
    print(datetime.datetime.today())
else:
    print('Unable to output responses because of one or more invalid inputs')
# Out:
# 2020-03-18 23:19:21.459047
# how old are you?
# 20
# what is your current college major?
# economics
# economics
# what year did you choose your current major?
# answers: ['freshman', 'sophmore', 'junior', 'senior', 'other']
# freshman
# freshman
# How important is median salary to you when considering a major?
# Not important at all ['1', '2', '3', '4', '5'] Very important
# 5
# 5
# How important is passion to you when considering a major?
# Not important at all ['1', '2', '3', '4', '5'] Very important
# 5
# 5
# would you say that you are passionate about your major?
# answers: ['Yes', 'No', 'Unsure']
# Yes
# Yes
# How important is percieved difficulty to you when considering a major?
# Not important at all ['1', '2', '3', '4', '5'] Very important
# 5
# 5
# did you consult your parents before picking a major?
# answers: ['Yes', 'No', 'Unsure']
# Yes
# Yes
# [20, 'economics', 'freshman', '5', '5', 'Yes', '5', 'Yes']
# 2020-03-18 23:20:32.757306
