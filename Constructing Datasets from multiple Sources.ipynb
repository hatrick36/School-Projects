# %%
import pandas as pd

# %%
games_df18 = pd.read_csv(r'C:\Users\pad39\Downloads\inclass-data-main\inclass-data-main\2018-games.csv')

# %%
games_df18.head()
# Out:
#    Unnamed: 0 GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  \
# 0       16196    2019-06-13  41800406            Final    1610612744
# 1       16197    2019-06-10  41800405            Final    1610612761
# 2       16198    2019-06-07  41800404            Final    1610612744
# 3       16199    2019-06-05  41800403            Final    1610612744
# 4       16200    2019-06-02  41800402            Final    1610612761
#
#    VISITOR_TEAM_ID  SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  ...  \
# 0       1610612761    2018    1610612744     110.0        0.488  ...
# 1       1610612744    2018    1610612761     105.0        0.447  ...
# 2       1610612761    2018    1610612744      92.0        0.449  ...
# 3       1610612761    2018    1610612744     109.0        0.396  ...
# 4       1610612744    2018    1610612761     104.0        0.372  ...
#
#    AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# ...

# %%
games_df19 = pd.read_csv(r'C:\Users\pad39\Downloads\inclass-data-main\inclass-data-main\2019-games.csv')

# %%
games_df = pd.concat([games_df18, games_df19])

# %%
games_df.drop(columns='Unnamed: 0', inplace=True)
games_df.head(2)
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2019-06-13  41800406            Final    1610612744       1610612761
# 1    2019-06-10  41800405            Final    1610612761       1610612744
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2018    1610612744     110.0        0.488        0.700  ...      28.0
# 1    2018    1610612761     105.0        0.447        0.778  ...      19.0
#
#    REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0      42.0    1610612761     114.0        0.476        0.793         0.394
# 1      43.0    1610612744     106.0        0.463        0.714         0.476
#
#    AST_away  REB_away  HOME_TEAM_WINS
# 0      25.0      39.0               0
# 1      27.0      37.0               0
#
# [2 rows x 21 columns]

# %%
teams_df = pd.read_csv(r'C:\Users\pad39\Downloads\inclass-data-main\inclass-data-main\teams.csv')
teams_df
# Out:
#     LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION       NICKNAME  \
# 0           0  1610612737      1949      2019          ATL          Hawks
# 1           0  1610612738      1946      2019          BOS        Celtics
# 2           0  1610612740      2002      2019          NOP       Pelicans
# 3           0  1610612741      1966      2019          CHI          Bulls
# 4           0  1610612742      1980      2019          DAL      Mavericks
# 5           0  1610612743      1976      2019          DEN        Nuggets
# 6           0  1610612745      1967      2019          HOU        Rockets
# 7           0  1610612746      1970      2019          LAC       Clippers
# 8           0  1610612747      1948      2019          LAL         Lakers
# 9           0  1610612748      1988      2019          MIA           Heat
# 10          0  1610612749      1968      2019          MIL          Bucks
# 11          0  1610612750      1989      2019          MIN   Timberwolves
# ...

# %%
merge1_df = pd.merge(teams_df,games_df,left_on='TEAM_ID', right_on='HOME_TEAM_ID')
merge1_df.head(2)
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION NICKNAME  \
# 0          0  1610612737      1949      2019          ATL    Hawks
# 1          0  1610612737      1949      2019          ATL    Hawks
#
#    YEARFOUNDED     CITY             ARENA  ARENACAPACITY  ... AST_home  \
# 0         1949  Atlanta  State Farm Arena        18729.0  ...     29.0
# 1         1949  Atlanta  State Farm Arena        18729.0  ...     29.0
#
#   REB_home TEAM_ID_away PTS_away FG_PCT_away  FT_PCT_away FG3_PCT_away  \
# 0     61.0   1610612754    135.0       0.459        0.846        0.400
# 1     44.0   1610612755    122.0       0.459        0.579        0.323
#
#    AST_away  REB_away  HOME_TEAM_WINS
# 0      22.0      43.0               0
# 1      27.0      57.0               1
#
# [2 rows x 35 columns]

# %%
merge1_df.shape
# Out:
# (2343, 35)

# %%
merge2_df = pd.merge(teams_df, games_df,left_on='TEAM_ID', right_on='HOME_TEAM_ID', how='outer')

# %%
merge2_df
# Out:
#       LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION  NICKNAME  \
# 0             0  1610612737      1949      2019          ATL     Hawks
# 1             0  1610612737      1949      2019          ATL     Hawks
# 2             0  1610612737      1949      2019          ATL     Hawks
# 3             0  1610612737      1949      2019          ATL     Hawks
# 4             0  1610612737      1949      2019          ATL     Hawks
# ...         ...         ...       ...       ...          ...       ...
# 2338          0  1610612744      1946      2019          GSW  Warriors
# 2339          0  1610612744      1946      2019          GSW  Warriors
# 2340          0  1610612744      1946      2019          GSW  Warriors
# 2341          0  1610612744      1946      2019          GSW  Warriors
# 2342          0  1610612744      1946      2019          GSW  Warriors
#
#       YEARFOUNDED          CITY             ARENA  ARENACAPACITY  ...  \
# ...

# %%
players18 = pd.read_csv(r'C:\Users\pad39\Downloads\inclass-data-main\inclass-data-main\2018-players.csv')
players19 = pd.read_csv(r'C:\Users\pad39\Downloads\inclass-data-main\inclass-data-main\2019-players.csv')
players_df = pd.merge(players18,players19,on='PLAYER_ID')
players_df
# Out:
#      Unnamed: 0_x     PLAYER_NAME_x   TEAM_ID_x  PLAYER_ID  SEASON_x  \
# 0             626     Kawhi Leonard  1610612761     202695      2018
# 1             627     Pascal Siakam  1610612761    1627783      2018
# 2             628        Marc Gasol  1610612761     201188      2018
# 3            1157        Marc Gasol  1610612763     201188      2018
# 4             629       Danny Green  1610612761     201980      2018
# ..            ...               ...         ...        ...       ...
# 533          1339       Abdul Gaddy  1610612760     203583      2018
# 534          1342    Andre Roberson  1610612760     203460      2018
# 535          1348      Norvel Pelle  1610612755     203658      2018
# 536          1350  Denzel Valentine  1610612741    1627756      2018
# 537          1353       C.J. Wilcox  1610612754     203912      2018
#
#      Unnamed: 0_y     PLAYER_NAME_y   TEAM_ID_y  SEASON_y
# 0             299     Kawhi Leonard  1610612746      2019
# ...
